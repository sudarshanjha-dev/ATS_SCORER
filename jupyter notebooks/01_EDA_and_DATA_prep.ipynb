# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

sns.set_style('whitegrid')
plt.rcParams['figure.figsize']=(12,6)

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
from datasets import load_dataset
dataset=load_dataset("0xnbk/resume-ats-score-v1-en")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Generating train split: 5099 examples [00:00, 14768.14 examples/s]
# Generating validation split: 1275 examples [00:00, 15969.45 examples/s]

# %%
df=pd.DataFrame(dataset['train'])
df
# Out:
#                                                    text  ats_score  \
# 0     SummaryI am seeking a position wherein I may u...       80.6
# 1     ProfileHighly motivated Sales Associate with e...       24.3
# 2     SummaryHaving achieved a milestone of 7 years ...       53.9
# 3     SummaryWireless communications engineer with e...       52.5
# 4     SummaryData Entry experienced and adept at inp...       59.2
# ...                                                 ...        ...
# 5094  Experience10 2019to06 2019Data AnalystAngi Hom...       25.8
# 5095  SummaryHaving achieved a milestone of 7 years ...       56.1
# 5096  Professional SummaryRELATED KNOWLEDGE AND SKIL...       27.4
# 5097  SummaryObtain a position where I can utilize m...       21.7
# 5098  Career OverviewMeticulous Senior Software Test...       55.3
#
#      original_label
# 0          Good Fit
# 1            No Fit
# 2     Potential Fit
# 3     Potential Fit
# 4     Potential Fit
# ...             ...
# 5094         No Fit
# 5095  Potential Fit
# 5096         No Fit
# 5097         No Fit
# 5098  Potential Fit
#
# [5099 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5099 entries, 0 to 5098
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            5099 non-null   str
#  1   ats_score       5099 non-null   float64
#  2   original_label  5099 non-null   str
# dtypes: float64(1), str(2)
# memory usage: 41.4 MB

# %%
df.describe()
# Out:
#          ats_score
# count  5099.000000
# mean     47.187452
# std      24.970249
# min      19.160000
# 25%      24.700000
# 50%      29.900000
# 75%      59.800000
# max      90.050000

# %%
# text columns summary
print("\nText Columns Summary:")
df.describe(include='object')
# Out:
# Text Columns Summary:
#                                                      text original_label
# count                                                5099           5099
# unique                                               5099              3
# top     SummaryI am seeking a position wherein I may u...         No Fit
# freq                                                    1           2565

# %%
full_dupes = df.duplicated().sum()
print(f"Full duplicate rows: {full_dupes}")
# Out:
# Full duplicate rows: 0

# %%
# ─── Section: Label Consistency ───────────────────────────────────────────────

# What labels exist? (spot the case inconsistency!)
print("Unique labels found:")
print(df['match_label'].value_counts())

# Is the casing consistent?
print(f"\nExpected 3 labels, got: {df['match_label'].nunique()} unique values")
print("Distinct values:", df['match_label'].unique())
# Out:
# Unique labels found:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jhasu\OneDrive\Desktop\ATS_SCORER\ATS_SCORER\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'match_label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 5
#       1 # ─── Section: Label Consistency ───────────────────────────────────────────────
#       2
#       3 # What labels exist? (spot the case inconsistency!)
#       4 print("Unique labels found:")
# ----> 5 print(df['match_label'].value_counts())
#       6
#       7 # Is the casing consistent?
#       8 print(f"\nExpected 3 labels, got: {df['match_label'].nunique()} unique values")
#
# File c:\Users\jhasu\OneDrive\Desktop\ATS_SCORER\ATS_SCORER\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\jhasu\OneDrive\Desktop\ATS_SCORER\ATS_SCORER\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'match_label'
